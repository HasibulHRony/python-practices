# %%
print("Assalamu alaikum")
# Out:
# Assalamu alaikum

# %%
shopping_list = ["chal", "dal",  "alu"]
print(shopping_list)
# Out:
# ['chal', 'dal', 'alu']

# %%
int_list = [1, 3, 5, 7]
print(int_list)
# Out:
# [1, 3, 5, 7]
